# %%
import pandas as pd
import numpy as np

# %%
datos1 = pd.read_csv("C:\\FCD\\PythonFundamental_Femsa\\athlete_events.csv")

# %%
#Crear un programa en Visual Studio que me permita saber cuál es el competidor más veterano que ha recibido medalla (oro, plata o bronce)
veterano = datos1[datos1["Medal"].notna()].max()
veterano
# Out:
# ID                                           135563
# Name                               ystein Pettersen
# Sex                                               M
# Age                                              73
# Height                                          223
# Weight                                          182
# Team                                            Zut
# NOC                                             ZIM
# Games                                   2016 Summer
# Year                                           2016
# Season                                       Winter
# City                                      Vancouver
# Sport                                     Wrestling
# Event     Wrestling Women's Middleweight, Freestyle
# Medal                                        Silver
# dtype: object

# %%
#Crear un programa en Visual Studio que me permita saber cuál es el competidor más joven que ha recibido medalla de oro
jovem_ouro = datos1[datos1["Medal"]=="Gold"].min()
jovem_ouro
# Out:
# ID                                    4
# Name                          A. Albert
# Sex                                   F
# Age                                  13
# Height                              136
# Weight                               28
# Team                            Algeria
# NOC                                 ALG
# Games                       1896 Summer
# Year                               1896
# Season                           Summer
# City                        Albertville
# Sport                       Aeronautics
# Event     Aeronautics Mixed Aeronautics
# Medal                              Gold
# dtype: object

# %%
#Encuentra al competidor más ganador de la historia y crea un csv con toda su información.

datosGold=datos1[datos1["Medal"] == "Gold"] #filtra onde a medalha seja Ouro
datosGold["Name"].value_counts() #contar registros de Ouro por Nome 
maior_campeao = datos1[datos1["Name"] == "Michael Fred Phelps, II"] 
maior_campeao.to_csv("Maior_Campeao") #gera arquivo csv
maior_campeao
# Out:
#            ID                     Name Sex   Age  Height  Weight  \
# 187887  94406  Michael Fred Phelps, II   M  15.0   193.0    91.0
# 187888  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187889  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187890  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187891  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187892  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187893  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187894  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187895  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187896  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187897  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187898  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187899  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# ...
